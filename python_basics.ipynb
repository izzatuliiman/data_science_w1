# %%
print("Welcome to Data Science")
# Out:
# Welcome to Data Science

# %%
x=5
print(x)
print("Value of x is : " , x)
print(type(x)) #print type ni maksudnya dia akan display apa type of x tu , so kat sini, x tu int
# Out:
# 5
# Value of x is :  5
# <class 'int'>
